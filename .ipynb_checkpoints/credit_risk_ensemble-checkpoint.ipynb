# %% [markdown]
# # Ensemble Learning
#
# ## Initial Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# ## Read the CSV and Perform Basic Data Cleaning

# %%
# Load the data
file_path = Path("Resources/LoanStats_2019Q1.csv")
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %%
df.dtypes
# Out:
# loan_amnt                     float64
# int_rate                      float64
# installment                   float64
# home_ownership                 object
# annual_inc                    float64
#                                ...
# total_bal_ex_mort             float64
# total_bc_limit                float64
# total_il_high_credit_limit    float64
# hardship_flag                  object
# debt_settlement_flag           object
# Length: 86, dtype: object

# %%
df["home_ownership"].count
# Out:
# <bound method Series.count of 0            RENT
# 1        MORTGAGE
# 2        MORTGAGE
# 3            RENT
# 4        MORTGAGE
#            ...
# 68812        RENT
# 68813        RENT
# 68814    MORTGAGE
# 68815    MORTGAGE
# 68816    MORTGAGE
# Name: home_ownership, Length: 68817, dtype: object>

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
# Creating an instance of label encoder
label_encoder = LabelEncoder()

# %%
# Fitting the label encoder
label_encoder.fit(df["home_ownership"])
# Out:
# LabelEncoder()

# %%
# List the classes identified by the label encoder
list(label_encoder.classes_)
# Out:
# ['ANY', 'MORTGAGE', 'OWN', 'RENT']

# %%
# Encode the months as an integer
df["home_ownership_le"] = label_encoder.transform(df["home_ownership"])
df.tail()
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 68812    10000.0    0.1502       346.76           RENT     26000.0
# 68813    12000.0    0.2727       368.37           RENT     63000.0
# 68814     5000.0    0.1992       185.62       MORTGAGE     52000.0
# 68815    40000.0    0.0646      1225.24       MORTGAGE    520000.0
# 68816    16000.0    0.1131       350.36       MORTGAGE     72000.0
#
#       verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 68812     Source Verified  Jan-2019    low_risk          n   9.60  ...
# 68813        Not Verified  Jan-2019    low_risk          n  29.07  ...
# 68814     Source Verified  Jan-2019    low_risk          n  14.86  ...
# 68815            Verified  Jan-2019    low_risk          n   9.96  ...
# 68816            Verified  Jan-2019    low_risk          n   7.02  ...
#
#        percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 68812               0.0                   0.0        0.0          20625.0
# 68813               0.0                   0.0        0.0          87939.0
# 68814               0.0                   1.0        0.0          30592.0
# 68815              12.5                   0.0        0.0        1033574.0
# 68816               0.0                   1.0        0.0         251486.0
#
#        total_bal_ex_mort  total_bc_limit total_il_high_credit_limit  \
# 68812             6798.0         11300.0                     5425.0
# 68813            60350.0         13500.0                    62939.0
# 68814            18611.0          3600.0                    18492.0
# 68815            95958.0        100800.0                    78634.0
# 68816            74835.0         23000.0                    63090.0
#
#        hardship_flag  debt_settlement_flag  home_ownership_le
# 68812              N                     N                  3
# 68813              N                     N                  3
# 68814              N                     N                  1
# 68815              N                     N                  1
# 68816              N                     N                  1
#
# [5 rows x 87 columns]

# %%
label_encoder.fit(df["initial_list_status"])
# Out:
# LabelEncoder()

# %%
list(label_encoder.classes_)
# Out:
# ['f', 'w']

# %%
# Encode the months as an integer
df["initial_list_status_le"] = label_encoder.transform(df["initial_list_status"])
df.tail()
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 68812    10000.0    0.1502       346.76           RENT     26000.0
# 68813    12000.0    0.2727       368.37           RENT     63000.0
# 68814     5000.0    0.1992       185.62       MORTGAGE     52000.0
# 68815    40000.0    0.0646      1225.24       MORTGAGE    520000.0
# 68816    16000.0    0.1131       350.36       MORTGAGE     72000.0
#
#       verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 68812     Source Verified  Jan-2019    low_risk          n   9.60  ...
# 68813        Not Verified  Jan-2019    low_risk          n  29.07  ...
# 68814     Source Verified  Jan-2019    low_risk          n  14.86  ...
# 68815            Verified  Jan-2019    low_risk          n   9.96  ...
# 68816            Verified  Jan-2019    low_risk          n   7.02  ...
#
#        pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# 68812                   0.0        0.0          20625.0             6798.0
# 68813                   0.0        0.0          87939.0            60350.0
# 68814                   1.0        0.0          30592.0            18611.0
# 68815                   0.0        0.0        1033574.0            95958.0
# 68816                   1.0        0.0         251486.0            74835.0
#
#        total_bc_limit  total_il_high_credit_limit hardship_flag  \
# 68812         11300.0                      5425.0             N
# 68813         13500.0                     62939.0             N
# 68814          3600.0                     18492.0             N
# 68815        100800.0                     78634.0             N
# 68816         23000.0                     63090.0             N
#
#        debt_settlement_flag  home_ownership_le  initial_list_status_le
# 68812                     N                  3                       1
# 68813                     N                  3                       1
# 68814                     N                  1                       1
# 68815                     N                  1                       0
# 68816                     N                  1                       1
#
# [5 rows x 88 columns]

# %%
label_encoder.fit(df["issue_d"])
# Out:
# LabelEncoder()

# %%
list(label_encoder.classes_)
# Out:
# ['Feb-2019', 'Jan-2019', 'Mar-2019']

# %%
# Encode the months as an integer
df["issue_d_le"] = label_encoder.transform(df["issue_d"])
df.tail()
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 68812    10000.0    0.1502       346.76           RENT     26000.0
# 68813    12000.0    0.2727       368.37           RENT     63000.0
# 68814     5000.0    0.1992       185.62       MORTGAGE     52000.0
# 68815    40000.0    0.0646      1225.24       MORTGAGE    520000.0
# 68816    16000.0    0.1131       350.36       MORTGAGE     72000.0
#
#       verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 68812     Source Verified  Jan-2019    low_risk          n   9.60  ...
# 68813        Not Verified  Jan-2019    low_risk          n  29.07  ...
# 68814     Source Verified  Jan-2019    low_risk          n  14.86  ...
# 68815            Verified  Jan-2019    low_risk          n   9.96  ...
# 68816            Verified  Jan-2019    low_risk          n   7.02  ...
#
#        tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 68812        0.0          20625.0             6798.0         11300.0
# 68813        0.0          87939.0            60350.0         13500.0
# 68814        0.0          30592.0            18611.0          3600.0
# 68815        0.0        1033574.0            95958.0        100800.0
# 68816        0.0         251486.0            74835.0         23000.0
#
#        total_il_high_credit_limit  hardship_flag debt_settlement_flag  \
# 68812                      5425.0              N                    N
# 68813                     62939.0              N                    N
# 68814                     18492.0              N                    N
# 68815                     78634.0              N                    N
# 68816                     63090.0              N                    N
#
#        home_ownership_le  initial_list_status_le  issue_d_le
# 68812                  3                       1           1
# 68813                  3                       1           1
# 68814                  1                       1           1
# 68815                  1                       0           1
# 68816                  1                       1           1
#
# [5 rows x 89 columns]

# %%
# howeowner dictionary
home_ownership_num = {
    "ANY": 0,
    "MORTGAGE": 1,
    "OWN": 2,
    "RENT": 3,
}

# %%
# howeowner' names encoded using the dictionary values
df["home_ownership_num"] = df["home_ownership"].apply(lambda x: home_ownership_num[x])
df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0          65687.0            38199.0          2000.0
# 1         271427.0            60641.0         41200.0
# 2          60644.0            45684.0          7500.0
# 3          99506.0            68784.0         19700.0
# 4         219750.0            25919.0         27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag  \
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
#   home_ownership_le  initial_list_status_le  issue_d_le  home_ownership_num
# 0                 3                       1           2                   3
# 1                 1                       1           2                   1
# 2                 1                       1           2                   1
# 3                 3                       1           2                   3
# 4                 1                       1           2                   1
#
# [5 rows x 90 columns]

# %%
# Dropping month and month_le columns
df.drop(["home_ownership", "home_ownership_le", "initial_list_status", "issue_d"], axis=1, inplace=True)
df.head(20)
# Out:
#     loan_amnt  int_rate  installment  annual_inc verification_status  \
# 0     10500.0    0.1719       375.35     66000.0     Source Verified
# 1     25000.0    0.2000       929.09    105000.0            Verified
# 2     20000.0    0.2000       529.88     56000.0            Verified
# 3     10000.0    0.1640       353.55     92000.0            Verified
# 4     22000.0    0.1474       520.39     52000.0        Not Verified
# 5     25000.0    0.1797       634.43     90000.0     Source Verified
# 6     20400.0    0.2000       540.48     51315.0     Source Verified
# 7     10000.0    0.1557       349.46     66000.0     Source Verified
# 8     14000.0    0.0881       443.96     45000.0        Not Verified
# 9     10000.0    0.1474       345.39     63295.0            Verified
# 10     8500.0    0.0819       267.11     75000.0        Not Verified
# 11    10000.0    0.1171       330.76     54000.0        Not Verified
# 12    30000.0    0.1033       642.30    100000.0     Source Verified
# 13    15800.0    0.1640       387.60     62000.0     Source Verified
# 14    18000.0    0.1557       433.63     60000.0            Verified
# 15    40000.0    0.2250      1537.99     54000.0            Verified
# 16    14400.0    0.1390       491.46    100350.0     Source Verified
# 17     9600.0    0.0881       304.43     92000.0        Not Verified
# 18    16000.0    0.1719       399.28     72500.0     Source Verified
# 19    20000.0    0.0756       622.68    175000.0        Not Verified
#
#    loan_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  tax_liens  \
# 0     low_risk          n  27.24          0.0             0.0  ...        0.0
# 1     low_risk          n  20.23          0.0             0.0  ...        0.0
# 2     low_risk          n  24.26          0.0             0.0  ...        0.0
# 3     low_risk          n  31.44          0.0             1.0  ...        0.0
# 4     low_risk          n  18.76          0.0             1.0  ...        0.0
# 5     low_risk          n  18.49          1.0             1.0  ...        0.0
# 6     low_risk          n  25.63          0.0             2.0  ...        0.0
# 7     low_risk          n   9.00          0.0             0.0  ...        0.0
# 8     low_risk          n  10.24          0.0             1.0  ...        0.0
# 9     low_risk          n  39.34          0.0             0.0  ...        0.0
# 10    low_risk          n  17.31          0.0             2.0  ...        0.0
# 11    low_risk          n  21.49          0.0             2.0  ...        0.0
# 12    low_risk          n   8.00          0.0             0.0  ...        0.0
# 13    low_risk          n   8.44          0.0             1.0  ...        0.0
# 14    low_risk          n  62.80          0.0             0.0  ...        0.0
# 15    low_risk          n  59.09          0.0             0.0  ...        0.0
# 16    low_risk          n  30.42          0.0             2.0  ...        0.0
# 17    low_risk          n  20.01          0.0             0.0  ...        0.0
# 18    low_risk          n  17.00          0.0             0.0  ...        0.0
# 19    low_risk          n  11.28          0.0             0.0  ...        0.0
#
#     tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0           65687.0            38199.0          2000.0
# 1          271427.0            60641.0         41200.0
# 2           60644.0            45684.0          7500.0
# 3           99506.0            68784.0         19700.0
# 4          219750.0            25919.0         27600.0
# 5          550717.0           418934.0         18800.0
# 6           40023.0            23469.0          3500.0
# 7           29300.0            22377.0          8400.0
# 8           25100.0             9724.0         12100.0
# 9          119822.0           102924.0         15300.0
# 10          75000.0            57756.0         18000.0
# 11         152500.0            42343.0         85000.0
# 12          50200.0            17323.0         29200.0
# 13         195700.0            18726.0         15900.0
# 14         196496.0           170509.0         10200.0
# 15         123858.0           107194.0         19100.0
# 16         156028.0           104873.0         49000.0
# 17          58335.0            43218.0          6300.0
# 18         217738.0            52114.0          8500.0
# 19          84966.0            65106.0         20500.0
#
#     total_il_high_credit_limit  hardship_flag  debt_settlement_flag  \
# 0                      61987.0              N                     N
# 1                      49197.0              N                     N
# 2                      43144.0              N                     N
# 3                      76506.0              N                     N
# 4                      20000.0              N                     N
# 5                     369051.0              N                     N
# 6                      27523.0              N                     N
# 7                      12500.0              N                     N
# 8                       3000.0              N                     N
# 9                      80722.0              N                     N
# 10                     57000.0              N                     N
# 11                     65500.0              N                     N
# 12                     20000.0              N                     N
# 13                      4100.0              N                     N
# 14                     73796.0              N                     N
# 15                     64858.0              N                     N
# 16                     88928.0              N                     N
# 17                     46535.0              N                     N
# 18                     49727.0              N                     N
# 19                     55785.0              N                     N
#
#     initial_list_status_le  issue_d_le  home_ownership_num
# 0                        1           2                   3
# 1                        1           2                   1
# 2                        1           2                   1
# 3                        1           2                   3
# 4                        1           2                   1
# 5                        1           2                   1
# 6                        1           2                   3
# 7                        1           2                   2
# 8                        0           2                   3
# 9                        1           2                   3
# 10                       1           2                   3
# 11                       1           2                   3
# 12                       1           2                   1
# 13                       1           2                   1
# 14                       1           2                   1
# 15                       1           2                   1
# 16                       1           2                   3
# 17                       1           2                   3
# 18                       1           2                   1
# 19                       1           2                   3
#
# [20 rows x 86 columns]

# %%
# Binary encoding using Pandas (single column)
LoanStats_encoded = pd.get_dummies(df)
LoanStats_encoded.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0    10500.0    0.1719       375.35     66000.0  27.24          0.0
# 1    25000.0    0.2000       929.09    105000.0  20.23          0.0
# 2    20000.0    0.2000       529.88     56000.0  24.26          0.0
# 3    10000.0    0.1640       353.55     92000.0  31.44          0.0
# 4    22000.0    0.1474       520.39     52000.0  18.76          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0             0.0       8.0      0.0     1609.0  ...
# 1             0.0      17.0      1.0    18368.0  ...
# 2             0.0       8.0      0.0    13247.0  ...
# 3             1.0      10.0      1.0    17996.0  ...
# 4             1.0      14.0      0.0     9091.0  ...
#
#    verification_status_Verified  loan_status_high_risk  loan_status_low_risk  \
# 0                             0                      0                     1
# 1                             1                      0                     1
# 2                             1                      0                     1
# 3                             1                      0                     1
# 4                             0                      0                     1
#
#    pymnt_plan_n  next_pymnt_d_Apr-2019  next_pymnt_d_May-2019  \
# 0             1                      0                      1
# 1             1                      0                      1
# 2             1                      0                      1
# 3             1                      0                      1
# 4             1                      0                      1
#
#    application_type_Individual  application_type_Joint App  hardship_flag_N  \
# 0                            1                           0                1
# 1                            1                           0                1
# 2                            1                           0                1
# 3                            1                           0                1
# 4                            1                           0                1
#
#    debt_settlement_flag_N
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
#
# [5 rows x 91 columns]

# %%
# Saving the encoded dataset
file_path = Path("Resources/loanStats_encoded.csv")
LoanStats_encoded.to_csv(file_path, index=False)

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
# Create our features
X = df.drop(columns="loan_status")
X = pd.get_dummies(X)
# Create our target
y = df["loan_status"]

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04  68817.000000
# mean   16677.594562      0.127718    480.652863  8.821371e+04     21.778153
# std    10277.348590      0.048130    288.062432  1.155800e+05     20.199244
# min     1000.000000      0.060000     30.890000  4.000000e+01      0.000000
# 25%     9000.000000      0.088100    265.730000  5.000000e+04     13.890000
# 50%    15000.000000      0.118000    404.560000  7.300000e+04     19.760000
# 75%    24000.000000      0.155700    648.100000  1.040000e+05     26.660000
# max    40000.000000      0.308400   1676.230000  8.797500e+06    999.000000
#
#         delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  68817.000000    68817.000000  68817.000000  68817.000000
# mean       0.217766        0.497697     12.587340      0.126030
# std        0.718367        0.758122      6.022869      0.336797
# min        0.000000        0.000000      2.000000      0.000000
# 25%        0.000000        0.000000      8.000000      0.000000
# 50%        0.000000        0.000000     11.000000      0.000000
# 75%        0.000000        1.000000     16.000000      0.000000
# max       18.000000        5.000000     72.000000      4.000000
#
#            revol_bal  ...  verification_status_Not Verified  \
# count   68817.000000  ...                      68817.000000
# mean    17604.142828  ...                          0.478007
# std     21835.880400  ...                          0.499520
# min         0.000000  ...                          0.000000
# 25%      6293.000000  ...                          0.000000
# 50%     12068.000000  ...                          0.000000
# 75%     21735.000000  ...                          1.000000
# max    587191.000000  ...                          1.000000
#
#        verification_status_Source Verified  verification_status_Verified  \
# count                         68817.000000                  68817.000000
# mean                              0.373992                      0.148001
# std                               0.483865                      0.355104
# min                               0.000000                      0.000000
# 25%                               0.000000                      0.000000
# 50%                               0.000000                      0.000000
# 75%                               1.000000                      0.000000
# max                               1.000000                      1.000000
#
#        pymnt_plan_n  next_pymnt_d_Apr-2019  next_pymnt_d_May-2019  \
# count       68817.0           68817.000000           68817.000000
# mean            1.0               0.383161               0.616839
# std             0.0               0.486161               0.486161
# min             1.0               0.000000               0.000000
# 25%             1.0               0.000000               0.000000
# 50%             1.0               0.000000               1.000000
# 75%             1.0               1.000000               1.000000
# max             1.0               1.000000               1.000000
#
#        application_type_Individual  application_type_Joint App  \
# count                 68817.000000                68817.000000
# mean                      0.860340                    0.139660
# std                       0.346637                    0.346637
# min                       0.000000                    0.000000
# 25%                       1.000000                    0.000000
# 50%                       1.000000                    0.000000
# 75%                       1.000000                    0.000000
# max                       1.000000                    1.000000
#
#        hardship_flag_N  debt_settlement_flag_N
# count          68817.0                 68817.0
# mean               1.0                     1.0
# std                0.0                     0.0
# min                1.0                     1.0
# 25%                1.0                     1.0
# 50%                1.0                     1.0
# 75%                1.0                     1.0
# max                1.0                     1.0
#
# [8 rows x 89 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
X.dtypes
# Out:
# loan_amnt                      float64
# int_rate                       float64
# installment                    float64
# annual_inc                     float64
# dti                            float64
#                                 ...
# next_pymnt_d_May-2019            uint8
# application_type_Individual      uint8
# application_type_Joint App       uint8
# hardship_flag_N                  uint8
# debt_settlement_flag_N           uint8
# Length: 89, dtype: object

# %%
# Split the X and y into X_train, X_test, y_train, y_test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
X_train.shape
# Out:
# (51612, 89)

# %% [markdown]
# ## Data Pre-Processing
#
# Scale the training and testing data using the `StandardScaler` from `sklearn`. Remember that when scaling the data, you only scale the features data (`X_train` and `X_testing`).

# %%
# Create the StandardScaler instance
from sklearn.preprocessing import LabelEncoder, StandardScaler
data_scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
# When fitting scaling functions, only train on the training dataset
X_scaler = data_scaler.fit(X_train)

# %%
# Scale the training and testing data
X_train_scaler= X_scaler.transform(X_train)
X_test_scaler = X_scaler.transform(X_test)

# %% [markdown]
# ## Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Display the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier only, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
brf = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
brf.fit(X_train, y_train)
# Out:
# BalancedRandomForestClassifier(random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = brf.predict(X_test_scaler)
balanced_accuracy_score(y_test,y_pred)
# Out:
# 0.5

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[   87,     0],
#        [17118,     0]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.01      1.00      0.00      0.01      0.00      0.00        87
#    low_risk       0.00      0.00      1.00      0.00      0.00      0.00     17118
#
# avg / total       0.00      0.01      0.99      0.00      0.00      0.00     17205

# %%
# List the features sorted in descending order by feature importance
# YOUR CODE HERE

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
# Train the Classifier
# YOUR CODE HERE

# %%
# Calculated the balanced accuracy score
# YOUR CODE HERE

# %%
# Display the confusion matrix
# YOUR CODE HERE

# %%
# Print the imbalanced classification report
# YOUR CODE HERE

# %% [markdown]
# ### Final Questions
#
# 1. Which model had the best balanced accuracy score?
#
#     YOUR ANSWER HERE.
#
# 2. Which model had the best recall score?
#
#     YOUR ANSWER HERE.
#
# 3. Which model had the best geometric mean score?
#
#     YOUR ANSWER HERE.
#
# 4. What are the top three features?
#
#     YOUR ANSWER HERE.
